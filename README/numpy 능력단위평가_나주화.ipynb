# %% [markdown]
# ### 로또 번호 자동 생성기를 만드시오.
# - 로또 번호 생성 기능을 함수로 정의하고 해당 함수를 호출하시오.
# - numpy를 이용하시오.

# %%
import numpy as np

def lotto():
    numbers = np.random.randint(1, 46, 6)
    print(numbers) 

lotto()
# Out:
# [23  9 43  7 17 42]

# %% [markdown]
# ### numpy 이용하여 pi(원주율) 값을 계산하시오.
# - 몬테 카를로 방법을 이용하시오.
# - 아래 이미지를 참고하여 pi(파이) 값을 출력하시오

# %%
import numpy as np
import matplotlib.pyplot as plt

n = 10000
count = 0
x_list = []
y_list = []
circle_x = []
circle_y = []
for i in range(n):
    x = np.random.rand()
    y = np.random.rand()
    x_list.append(x)
    y_list.append(y)

    if np.sqrt(x ** 2 + y ** 2) < 1: 
        circle_x.append(x) 
        circle_y.append(y) 
        count += 1

plt.figure(figsize=(5, 5))      
plt.xlim(0, 1)
plt.ylim(0, 1)
cx = np.cos(np.linspace(0, np.pi/2, 10000))
cy = np.sin(np.linspace(0, np.pi/2, 10000))
plt.plot(cx, cy, color = 'black') ### 원의 경계를 그려주는 부분
plt.scatter(x_list, y_list)
plt.scatter(circle_x, circle_y, c='r') 

print('pi:', 4 * count / n)
# Out:
# pi: 3.1216
